# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("../data/raw/Credit_Card_Fraud_Analytics_v4.xlsx")

# %%
df_copy=df.copy()

# %%
# df.head() # for first five row
# df.shape
# df.tail() # for last five row
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 39 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   trans_date_trans_time            11000 non-null  datetime64[ns]
#  1   merchant                         11000 non-null  object
#  2   category                         11000 non-null  object
#  3   amt                              11000 non-null  float64
#  4   gender                           11000 non-null  object
#  5   city                             11000 non-null  object
#  6   state                            11000 non-null  object
#  7   lat                              11000 non-null  float64
#  8   long                             11000 non-null  float64
#  9   city_pop                         11000 non-null  int64
#  10  job                              11000 non-null  object
# ...

# %%
df.describe()
df.describe(include='object')
# Out:
#                                merchant       category gender     city  state  \
# count                             11000          11000  11000    11000  11000
# unique                              693             14      2      832     50
# top     fraud_Kling, Howe and Schneider  gas_transport      F  Phoenix     TX
# freq                                 33           1113   5986       55    754
#
#                       job Customer_ID Age_Group Customer_Segment Device_Type  \
# count               11000       11000     11000            11000       11000
# unique                475       11000         4                3          10
# top     Systems developer  CUST000001     41-60         Standard         POS
# freq                   80           1      4533             6521        2661
#
#        Transaction_Channel Authentication_Method OTP_Verified Card_Present  \
# count                11000                 11000        11000        11000
# ...
